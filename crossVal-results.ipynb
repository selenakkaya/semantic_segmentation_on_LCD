# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# wire k=3

# %% [markdown]
# ----

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# wire k=4

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mesh k=3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mesh k=4
